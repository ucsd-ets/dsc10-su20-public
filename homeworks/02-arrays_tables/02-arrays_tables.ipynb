# %% [markdown]
# # Homework 2: Arrays and Tables
#
# ## Due Thursday, July 16th at 11:59pm

# %% [markdown]
# Please complete this notebook by filling in the cells provided. Before you begin, execute the following cell to load the provided tests. Each time you start your server, you will need to execute this cell again to load the tests.

# %%
# Don't change this cell; just run it. 
import numpy as np
import babypandas as bpd
import math

import otter
otter = otter.Notebook('tests')

# %% [markdown]
# ### Reading
#
# - Textbook [Chapter 2](https://eldridgejm.github.io/dive_into_data_science/02-data_sets/arrays.html)
#
# ### Deadline
#
# This assignment is due Thursday, July 16th at 11:59pm. You are given six slip days thoughout the quarter which can extend the deadline by one day. See the syllabus for more details. With the exception of using slip days, late work will not be accepted unless you have made special arrangements with your instructor.
#
# **Important**: The `otter` tests don't usually tell you that your answer is correct. More often, they help catch careless mistakes. It's up to you to ensure that your answer is correct. If you're not sure, ask someone (not for the answer, but for some guidance about your approach).
#
# Directly sharing answers is not okay, but discussing problems with the course staff or with other students is encouraged.
#
# You should start early so that you have time to get help if you're stuck. A calendar with lab hour times and locations appears on [the course webpage](https://ucsd-ets.github.io/dsc10-su20/office_hours.html).

# %% [markdown]
# ## 1. Arrays

# %% [markdown]
# **Question 1.1** Make an array called `weird_numbers` containing the following numbers (in the given order):
#
# 1. The factorial of 5.
# 2. The mathematical constant $\pi$.
# 3. The logarithm of 12, in base 3.
# 4. 25 degrees, in radians.
# 5. The square root of 7.
#
# *Hint:* Take a look at the functions and constants in the `math` module.

# %%
weird_numbers = ...
weird_numbers

# %%
otter.check('q1_1')

# %% [markdown]
# **Question 1.2.** Make an array called `words` containing the following three strings:
# * The textbook
# * we use in dsc10 is
# * "Dive Into Data Science"

# %%
words = ...
words

# %%
otter.check('q1_2')

# %% [markdown]
# Strings have a method called `join`.  `join` takes one argument, an array of strings. It returns a single string. Specifically, the value of `a_string.join(an_array)` is a single string that's the concatenation ("putting together") of all the strings in `an_array`, **except** `a_string` is inserted in between each string.
#
# **Question 1.3.** Use the array `words` and the method `join` to make two strings:
#
# 1. The textbook, we use in dsc10 is, "Dive Into Data Science" (call this one `with_commas`)
# 2. The textbook we use in dsc10 is "Dive Into Data Science" (call this one `with_spaces`)
#
# *Hint:* If you're not sure what `join` does, first try just calling, for example, `"foo".join(words)` .

# %%
with_commas = ...
with_commas

# %%
with_spaces = ...
with_spaces

# %%
otter.check('q1_3')

# %% [markdown]
# Now let's get some practice with accessing individual elements of arrays.  In Python (and in many programming languages), elements are accessed by *integer position*, with the position of the first element being zero.

# %% [markdown]
# **Question 1.4.** The cell below creates an array of strings. What is the position of `'third'` in the array?

# %%
some_strings = np.array(['first', 'second', 'third', 'fourth', 'fifth', 'sixth', 'last'])

# %%
index_of_third = ...
index_of_third

# %%
otter.check('q1_4')

# %% [markdown]
# *Negative* positions are used to access items at the end of the array. For example:

# %%
some_strings[-1]

# %% [markdown]
# **Question 1.5.** Assign `second_to_last_element` to the second to last element of the array `some_strings`.

# %%
second_to_last_element = ...
second_to_last_element

# %%
otter.check('q1_5')

# %% [markdown]
# **Question 1.6.** Suppose you have an array with 147 elements. Assign the position of the middle element to `mid_index` below.

# %%
mid_index = ...
mid_index

# %%
otter.check('q1_6')

# %% [markdown]
# ## 2. Basic Array Arithmetic

# %% [markdown]
# The following table contains six siblings and their weekly allowance from their parents:
#
# |Sibling|Weekly allowance (\$)|Weekly expense (\$)|
# |---|---|---|
# |Sarah|3|3|
# |Dave|2|1|
# |John|4|2.5|
# |Ashley|6|3.5|
# |June|12|10|
# |Rob|8|3|
#
# **Question 2.1.** By hand, create a new array called `allowances` which has the weekly allowance of each sibling.

# %%
allowances = ...
allowances

# %%
otter.check('q2_1')

# %% [markdown]
# **Question 2.2.** If every sibling is given a raise of $3/week by their parents, how much money does each sibling make per week? Update the allowances by creating a new array `new_allowances_constant`.

# %%
new_allowances_constant = ...
new_allowances_constant

# %%
otter.check('q2_2')

# %% [markdown]
# **Question 2.3.** If instead, the parents decided to give each sibling a 25% raise, how much money does each sibling make per week? Update the allowances in the array `new_allowances_percent`.

# %%
new_allowances_percent = ...
new_allowances_percent

# %%
otter.check('q2_3')

# %% [markdown]
# **Question 2.4.** Calculate how much each sibling receives per day for allowance in dollars (be sure to round each allowance to the nearest cent!). Assign your answer to the name `allowances_by_day`.

# %%
allowances_by_day = ...
allowances_by_day

# %%
otter.check('q2_4')

# %% [markdown]
# **Question 2.5.** By hand, create an array called `expenses` which contains the weekly expenses. Calculate the amount of remaining money after each sibling spends a portion of their allowance on expenses, assigning the amounts to the variable `remaining`.

# %%
remaining = ...
remaining

# %%
otter.check('q2_5')

# %% [markdown]
# ## 3. Dead Presidents

# %% [markdown]
# The file named `president_births.csv` contains data on how each US president was when they died.

# %% [markdown]
# **Question 3.1.** Read the CSV file into a dataframe called `president_data`.

# %%
president_data = ...
president_data

# %%
otter.check('q3_1')

# %% [markdown]
# **Question 3.2.** Set the index so that each row is labeled by the president's name. Save the result in a variable called `presidents`

# %%
presidents = ...
presidents

# %%
otter.check('q3_2')

# %% [markdown]
# **Question 3.3.** Using dataframe operations, determine how long, in days, John F. Kennedy lived.

# %%
grant_days = ...
grant_days

# %%
otter.check('q3_3')

# %% [markdown]
# **Question 3.4.** Starting with `presidents`, create a new dataframe called `with_minutes` that contains a column named `With_Minutes` that has the duration of each president's life, in minutes.

# %%
with_minutes = ...
with_minutes

# %%
otter.check('q3_4')

# %% [markdown]
# **Question 3.5.** Using table operations, find the name of the president who lived the longest (in terms of number of days).

# %%
oldest_president = ...
oldest_president

# %%
otter.check('q3_5')

# %% [markdown]
# **Question 3.6.** Create a new table called `before_1920` which contains only those presidents in `presidents` who were born before the year 1920.

# %%
before_1920 = ...
before_1920

# %%
otter.check('q3_6')

# %% [markdown]
# **Question 3.7.** What was the median age of a president at their death (in years)?

# %%
med_years = ...
med_years

# %%
otter.check('q3_7')

# %% [markdown]
# **Question 3.8.** Unsuprisingly, the average lifespan (in years) of presidents born in 1880 or after is longer than the average lifespan of presidents born before 1880. Using table operations, assign `difference_years` to the difference between the two averages (your answer should be positive).

# %%
difference_years = ...
difference_years

# %%
otter.check('q3_8')

# %% [markdown]
# **Question 3.9.** Starting with `presidents`, create a table of all of the presidents who were born before 1850 but died after 1900.

# %%
born_before_1850_died_after_1900 = ...
born_before_1850_died_after_1900

# %%
otter.check('q3_9')

# %% [markdown]
# ## 4. Shark Attacks

# %% [markdown]
# The file `sharks.csv` contains data on the number of shark attacks by year. Let's read it into Python:

# %%
attacks_table = bpd.read_csv('sharks.csv').set_index('Year')
attacks_table

# %% [markdown]
# The table only has one column, `Attacks`. Lets pull it out of the table and work with it alone:

# %%
attacks = attacks_table.get('Attacks')
attacks

# %% [markdown]
# Note that `attacks` is not a DataFrame, it is a Series. Columns of DataFrames are Series objects, and act much like arrays.

# %% [markdown]
# **Question 4.1.** What's the smallest and largest number of shark attacks in a given year? What is the average number of shark attacks between 1930 and 2017?

# %%
smallest = ...
smallest

# %%
largest = ...
largest

# %%
average = ...
average

# %%
otter.check('q4_1')

# %% [markdown]
# **Question 4.2.** How many shark attacks were there in 1999?

# %%
number_in_99 = ...
number_in_99

# %%
otter.check('q4_2')

# %% [markdown]
# **Question 4.3.** In which year were there the second most shark attacks?
#
# *Hint*: Series have a `sort_values` method, just like DataFrames.

# %%
second_deadliest_year = ...
second_deadliest_year

# %%
otter.check('q4_3')

# %% [markdown]
# **Question 4.4.** What is the largest increase in attacks experienced between consecutive years?
#
# *Hint*: You'll need an array arithmetic function [mentioned in the textbook](https://eldridgejm.github.io/dive_into_data_science/02-data_sets/arrays.html).

# %%
biggest_increase = ...
biggest_increase

# %%
otter.check('q4_4')

# %% [markdown]
# **Question 4.5.** What percentage of shark attacks, during the 88 years recorded in the array, occured in the first 62 years? Your answer should be a decimal.

# %%
pct_in_first_62_years = ...
pct_in_first_62_years

# %%
otter.check('q4_5')

# %% [markdown]
# ## 5. Modern Business Analytics

# %% [markdown]
# The file `inventory.csv` contains information about the inventory at a fruit stand at the end of the day.  Each row represents the contents of one box of fruit.

# %%
inventory = bpd.read_csv('inventory.csv').set_index('box ID')
inventory

# %% [markdown]
# **Question 5.1.** Does each box at the fruit stand contain a different fruit? Set `all_different` to "Yes" if each box contains a different fruit or to "No" if multiple boxes contain the same fruit

# %%
all_different = ...
all_different

# %%
otter.check('q5_1')

# %% [markdown]
# **Question 5.2.** How many pieces of fruit did the store start with that day (in total)?

# %%
total_fruit = ...
total_fruit

# %%
otter.check('q5_2')

# %% [markdown]
# **Question 5.3.** What was the store's total revenue (the total price of all fruits sold) on that day?

# %%
total_revenue = ...
total_revenue

# %%
otter.check('q5_3')

# %% [markdown]
# **Question 5.4.** What was the revenue made from strawberries sold that day?

# %%
total_strawberries = ...
total_strawberries

# %%
otter.check('q5_4')

# %% [markdown]
# **Question 5.5.** Create a table with a new column, called `remaining_value` that indicates the total remaining value of the fruit still in each box at the end of the day. Assign this table the name `with_remaining`.

# %%
with_remaining = ...
with_remaining

# %%
otter.check('q5_5')

# %% [markdown]
# **Question 5.6.** Create a table which has one column, `sold count`, that contains the amount sold of each type of fruit. The index of this table will contain the fruit types as row label. There should only be 6 rows.

# %%
sold_each_fruit = ...
sold_each_fruit

# %%
otter.check('q5_6')

# %% [markdown]
# # Finish Line
#
# Congratulations! You are done with homework 2.
#
# To submit your assignment:
#
# 1. Select `Kernel -> Restart & Run All` to ensure that you have executed all cells, including the test cells.
# 2. Read through the notebook to make sure everything is fine and all tests passed.
# 3. Run the cell below to run all tests, and make sure that they all pass.
# 4. Download your notebook using `File -> Download as -> Notebook (.ipynb)`, then upload your notebook to Gradescope.

# %%
# For your convenience, you can run this cell to run all the tests at once!
otter.check_all()
